# %% [markdown]
# making a game

# %%
# Lord of Python
# a hero, mini boss, a final monster, using potion/items in battle, 3 different locations

from typing import TypedDict, List, Literal, Dict
import random, time 

class CharacterTypes(TypedDict):
    'name': str
    'health': int
    'attack_power': int
    'defense': int
    'strength': str 

character = {
    'name': 'Hero',
    'health': 90,
    'attack_power': 10,
    'defense': 10,
    'strength': '',
}
