# %% [markdown]
# controlling the flow of code

# %% [markdown]
# # controlling pyhton's flow
#
# - [ ] conditional statements
# - [ ] in/or/not
# - [ ] truthy/falsy
# - [ ] if/elif/else (if statements)
# - [ ] one line if statements
# - [ ] hashmaps

# %%
from datetime import datetime 
from typing import TypedDict

# comparisons
# == , != , < , > , <= , >=
class Person(TypedDict):
    name: str
    birth_year: int
    

drinking_age: int = 22
current_year: int = datetime.now().year 

name: str = input('enter your name: ')
birth_year: str = input('enter your age: ')

person1: Person = {
    'name': name,
    'birth_year': birth_year,
}

if birth_year.isnumeric():
    person1['birth_year'] = int(birth_year)
    print(f'is {person1['name']} old enough to drink? {(current_year - person1['birth_year']) >= drinking_age}')
else:
    print('A year is an integer dummy')
# Out:
# is syd old enough to drink? True

# %%
person1['birth_year'] == current_year
# Out:
# False

# %%
person1['birth_year'] > current_year
# Out:
# False

# %%
person1['name'] == 'syd'
# Out:
# True

# %%
person1
# Out:
# {'name': 'syd', 'birth_year': 15}

# %%
person1['name'].lower() == 'Syd'.lower()
# Out:
# True

# %%
if (current_year - person1['birth_year']) >= drinking_age:
    print(f'{person1['name']} can buy alcohol')
# Out:
# syd can buy alcohol

# %%
# is/or/not/and - boolean statements that do exactly what they are

type(person1['name']) is str
# Out:
# True

# %%
person1['name'] == 'syd'
# Out:
# True

# %%
type(person1['name']) is str
# Out:
# True

# %%
#not reverses statement

if not '':
    print('this is truthy')
else:
    print('this is falsy')
# Out:
# this is truthy

# %%
if  person1['birth_year'] and type(person1['birth_year']) == str:
    print('birth year exists and is a string')
elif person1['birth_year'] and type(person1['birth_year']) == int:
    print('birth_year exists and birth year is an int')
else:
    print('birth year is either not existing or not a string')
# Out:
# birth_year exists and birth year is an int

# %%
a = 0
b = []
c = ['something']
d = ['']

# or statement needs just one true
if a or b:
    print('one of these is truthy')
elif a or d:
    print('the second block is truthy')
elif a or c:
    print('block 3 is truthy')
else:
    print('no block is truthy')
# Out:
# the second block is truthy

# %%
name_list = ['syd', 'bob', 'nate', 'jen']
chosen_name = input('what is your name?')

#in checks if anything is in an item
if chosen_name in name_list:
    print(f'{chosen_name} exists in {name_list}')
else:
    print('too bad that sucks')
# Out:
# Jen exists in ['syd', 'bob', 'nate', 'jen']

# %%
# nested if statements - russian nesting doll
